# %%
print("5 divided by 2 is", 5 // 2, "with a remainder of", 5 % 2)
# Out:
# 5 divided by 2 is 2 with a remainder of 1

# %%
min_salary = 20_000 
max_salary = 80_000

average_salary = (min_salary + max_salary) / 2

average_salary
# Out:
# 50000.0

# %%
applicant_skill = 'SQL'
job_skill = 'SQL'
result = 'No Skills Match'

if applicant_skill == job_skill:
    result = 'Skills Match!'

result
# Out:
# 'Skills Match!'

# %%
years_experience = 3

if applicant_skill == job_skill and years_experience < 2:
    result = 'Junior Data Analyst position.'
elif applicant_skill == job_skill and years_experience <= 5:
    result = 'Mid-level Data Analyst position.'
elif applicant_skill == job_skill and years_experience > 5:
    result = 'Senior Data Analyst position.'

result
# Out:
# 'Mid-level Data Analyst position.'

# %%
if applicant_skill != job_skill:  #!= significa se é diferente 
    result = 'Skills still needed'
elif applicant_skill== job_skill and years_experience < 2:
    result = 'More experience needed'
else:
    result = 'Experience matches!'

result
# Out:
# 'Experience matches!'

# %%
#agora, um pouco sobre listas
#usado para coleção de items em gerais

job_skills = ['sql','tableau','excel']
job_skills[1] ='bigquery'
job_skills.append('looker') #adiciona à lista

job_skills
# Out:
# ['sql', 'bigquery', 'excel', 'looker']

# %%
job_skills.insert(2,'python')

job_skills
# Out:
# ['sql', 'bigquery', 'python', 'excel', 'looker']

# %%
skills1 = ['SQL', 'Tableau']
skills2 = ['Excel']

skills3 = skills1 + skills2
skills3
# Out:
# ['SQL', 'Tableau', 'Excel']

# %%
skills4 = ['Python', 'Power BI']

for x in skills3:  #exemplo de repetição
    skills4.append(x)

skills4
# Out:
# ['Python', 'Power BI', 'SQL', 'Tableau', 'Excel']

# %%
skills = ['Python', 'SQL', 'Excel']

first_two = skills[0:2]
first_two
# Out:
# ['Python', 'SQL']

# %%
#agora, um pouco sobre dictionaries
#conseguem ser puxados pela key,

job_type_skills = {
    'database': 'postgresql',
    'language': 'python',
    'library': 'pandas'
}

job_type_skills['language']
# Out:
# 'python'

# %%
job_type_skills.keys()
# Out:
# dict_keys(['database', 'language', 'library'])

# %%
job_type_skills.pop('library')  #diferente do delete da list
job_type_skills
# Out:
# {'database': 'postgresql', 'language': 'python'}

# %%
job_type_skills.update({'cloud': 'google cloud', 'version_control': 'git'})

job_type_skills
# Out:
# {'database': 'postgresql',
#  'language': 'python',
#  'cloud': 'google cloud',
#  'version_control': 'git'}

# %%
#agora, um pouco sobre sets
#lembrado que sets são valores únicos, e não consegue puxar pelo index

job_skills = {'tableau', 'sql', 'python', 'statistics'}
job_skills.add('looker')

job_skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableau'}

# %%
skill_list = ['python', 'sql', 'statistics', 'tableau', 'python', 'sql', 'statistics', 'tableau']

set(skill_list)
# Out:
# {'python', 'sql', 'statistics', 'tableau'}

# %%
#por fim, as tupples, que são imutáveis

job_skills = ('python', 'sql', 'statistics', 'tableau')

job_skills
# Out:
# ('python', 'sql', 'statistics', 'tableau')

# %%
job_skills_list = list(job_skills)
job_skills_list.append('excel')
job_skills_tuple = tuple(job_skills_list)

job_skills_tuple
# Out:
# ('python', 'sql', 'statistics', 'tableau', 'excel')

# %%
#conseguimos adicionar uma tupple dentro de uma tupple

job_skills_new_tuple = ('r', 'postgresql',)
job_skills += job_skills_new_tuple

job_skills
# Out:
# ('python', 'sql', 'statistics', 'tableau', 'r', 'postgresql')

# %%
print(f'I have these skills: {", ".join(skills)}')
# Out:
# I have these skills: Python, SQL, Excel
